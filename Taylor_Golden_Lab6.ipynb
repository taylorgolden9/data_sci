# %% [markdown]
# <a href="https://colab.research.google.com/github/taylorgolden9/data_sci/blob/main/Taylor_Golden_Lab6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import urllib.request

#the most important line of code

# %%
urllib.request.urlretrieve('https://raw.githubusercontent.com/williamedwardhahn/Probability_Statistics/main/cereal_data.csv','cereal_data.csv')

#this connects the data from the url to colab
# Out:
# ('cereal_data.csv', <http.client.HTTPMessage at 0x7f74e3ce9880>)

# %%
cereal_data = pd.read_csv('cereal_data.csv')  

#this pulls the data from the url so that it can be used within colab

# %% [markdown]
# Name: Name of cereal
#
# mfr: Manufacturer of cereal
#
#     A = American Home Food Products
#
#     G = General Mills
#
#     K = Kelloggs
#
#     N = Nabisco
#
#     P = Post
#
#     Q = Quaker Oats
#
#     R = Ralston Purina
#
# type:
#
#     cold
#
#     hot
#
# calories: calories per serving
#
# protein: grams of protein
#
# fat: grams of fat
#
# sodium: milligrams of sodium
#
# fiber: grams of dietary fiber
#
# carbo: grams of complex carbohydrates
#
# sugars: grams of sugars
#
# potass: milligrams of potassium
#
# vitamins: vitamins and minerals - 0, 25, or 100,
# indicating the typical percentage of FDA recommended
#
# shelf: display shelf (1, 2, or 3, counting from the floor)
#
# weight: weight in ounces of one serving
#
# cups: number of cups in one serving
#
# rating: a rating of the cereals

# %%
cereal_data

#all of the data from the url showcased on colab
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
cereal_data["sugars"].mean()

#the mean value of sugars using the values from the data set pulled from the url
# Out:
# 6.922077922077922

# %%
cereal_data[["calories", "sugars"]].mean()

#the mean value of calories and sugars using the values from the data set pulled from the url
# Out:
# calories    106.883117
# sugars        6.922078
# dtype: float64

# %%
cereal_data.describe()

#shows the different values of each nutrition fact from the data set
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# ...

# %%
cereal_data[["calories", "sugars"]]

#shows only the calories and sugars
# Out:
#     calories  sugars
# 0         70       6
# 1        120       8
# 2         70       5
# 3         50       0
# 4        110       8
# ..       ...     ...
# 72       110       3
# 73       110      12
# 74       100       3
# 75       100       3
# 76       110       8
#
# [77 rows x 2 columns]

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["calories"]],'.')

#plots all data of 'sugars' and 'calories' onto a graph

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

#plots all data of 'fat' and 'calories' onto a graph

# %%
plt.plot(cereal_data[["fat"]],cereal_data[["calories"]],'.')

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["carbo"]],'.')

##plots all data of 'sugars' and 'carbs' onto a graph

# %%
plt.plot(cereal_data[["sugars"]],cereal_data[["vitamins"]],'.')

#plots all data of 'sugars' and 'vitamins' onto a graph

# %%
X = cereal_data[["sugars"]]
Y = cereal_data[["calories"]]

#labels the 'sugars' as the 'x value' and 'calories' as the 'y value'

# %%
from sklearn.linear_model import LinearRegression
linear_regressor = LinearRegression() 

#so that colab can understand the following lines of code

# %%
linear_regressor.fit(X, Y)
Y_pred = linear_regressor.predict(X)

#creates the graph

# %%
plt.plot(X, Y,'.')
plt.plot(X, Y_pred, color='red')
plt.show()

#shows the graph on colab

# %%
import numpy as np
import matplotlib.pyplot as plt

#so that colab can understand the following lines of code

# %%
x = np.linspace(0,10,50)

#defines x

# %%
noise = 10 * np.random.randn(50,)

# %%
y = 3 * x + 7 + noise

#defines y

# %%
plt.plot(x,y,'.');

#plots x and y using plot points

# %%
m_guess = 1
b_guess = 1

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

#plots the data above in green, and in red plots the guess x and y in red

# %%
m_guess = 5
b_guess = 15

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

#changes the guess data

# %%
m_guess = 3
b_guess = 7

y_guess = m_guess * x + b_guess

plt.plot(x,y_guess,'r.');
plt.plot(x,y,'g.');

#changes the guess values again

# %%
loss = np.sum((y_guess - y)**2)

#the equation to figure out the loss

# %%
loss

#shows the loss value
# Out:
# 83493.88772211947

# %%
for m_guess in np.linspace(-10,10,10):
    for b_guess in np.linspace(-10,10,10):
        
        y_guess = m_guess * x + b_guess

        plt.plot(x,y_guess,'r.');
        plt.plot(x,y,'g.');
        plt.show()

        loss = np.sum((y_guess - y)**2)

        print(loss,m_guess,b_guess)
# Out:
# 442803.4820052807 -10.0 -10.0
# 424070.98953376396 -10.0 -7.777777777777778
# 405832.3242227411 -10.0 -5.555555555555555
# 388087.48607221217 -10.0 -3.333333333333333
# 370836.4750821769 -10.0 -1.1111111111111107
# 354079.29125263554 -10.0 1.1111111111111107
# 337815.93458358804 -10.0 3.333333333333334
# 322046.4050750343 -10.0 5.555555555555557
# 306770.70272697456 -10.0 7.777777777777779
# 291988.8275394084 -10.0 10.0
# 330899.66027199157 -7.777777777777778 -10.0
# 314636.303602944 -7.777777777777778 -7.777777777777778
# 298866.77409439033 -7.777777777777778 -5.555555555555555
# 283591.0717463304 -7.777777777777778 -3.333333333333333
# 268809.1965587644 -7.777777777777778 -1.1111111111111107
# 254521.14853169216 -7.777777777777778 1.1111111111111107
# 240726.92766511376 -7.777777777777778 3.333333333333334
# 227426.53395902918 -7.777777777777778 5.555555555555557
# 214619.96741343845 -7.777777777777778 7.777777777777779
# 202307.2280283415 -7.777777777777778 10.0
# ...

# %%
#shows an unnecessary amount of plot graphs

# %%
best_loss = 100000
best_m = 0
best_b = 0 

for m_guess in np.linspace(-10,10,20):
    for b_guess in np.linspace(-10,10,20):
        
        y_guess = m_guess * x + b_guess

        loss = np.sum((y_guess - y)**2)

        if loss < best_loss:
            
            best_loss = loss
            best_m = m_guess
            best_b = b_guess 

            plt.plot(x,y_guess,'r.');
            plt.plot(x,y,'g.');
            plt.show()

            print(loss,m_guess,b_guess)
# Out:
# 96506.24795549935 -4.736842105263158 7.894736842105264
# 92730.61233600893 -4.736842105263158 8.94736842105263
# 89065.7800406182 -4.736842105263158 10.0
# 86175.79962624933 -3.6842105263157894 3.6842105263157894
# 82510.96733085864 -3.6842105263157894 4.7368421052631575
# 78956.93835956765 -3.6842105263157894 5.789473684210526
# 75513.71271237641 -3.6842105263157894 6.842105263157894
# 72181.29038928487 -3.6842105263157894 7.894736842105264
# 68959.67139029306 -3.6842105263157894 8.94736842105263
# 65848.85571540098 -3.6842105263157894 10.0
# 63365.907920173944 -2.6315789473684212 3.6842105263157894
# 60255.09224528186 -2.6315789473684212 4.7368421052631575
# 57255.0798944895 -2.6315789473684212 5.789473684210526
# 54365.87086779685 -2.6315789473684212 6.842105263157894
# 51587.46516520395 -2.6315789473684212 7.894736842105264
# 48919.86278671075 -2.6315789473684212 8.94736842105263
# 46363.06373231728 -2.6315789473684212 10.0
# ...

# %%
#shows an unnecessary amount of plot graphs
